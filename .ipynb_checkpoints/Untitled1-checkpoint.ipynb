# %%
import tensorflow as tf
import tensorflow_hub as hub

module_handle = "https://tfhub.dev/google/faster_rcnn/openimages_v4/inception_resnet_v2/1"

detector = hub.load(module_handle).signatures["default"]
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\google\protobuf\internal\containers.py in __getitem__(self, key)
#     577     try:
# --> 578       return self._values[key]
#     579     except KeyError:
#
# KeyError: 'dtype'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-792ae604ccbe> in <module>
#       4 module_handle = "https://tfhub.dev/google/faster_rcnn/openimages_v4/inception_resnet_v2/1"
#       5
# ----> 6 detector = hub.load(module_handle).signatures["default"]
#
# ~\anaconda3\lib\site-packages\tensorflow_hub\module_v2.py in load(handle, tags, options)
#     112         module_path, tags=tags, options=options)
#     113   else:
# --> 114     obj = tf_v1.saved_model.load_v2(module_path, tags=tags)
#     115   obj._is_hub_module_v1 = is_hub_module_v1  # pylint: disable=protected-access
#     116   return obj
#
# ~\anaconda3\lib\site-packages\tensorflow\python\saved_model\load.py in load(export_dir, tags, options)
#     601     ValueError: If `tags` don't match a MetaGraph in the SavedModel.
#     602   """
# --> 603   return load_internal(export_dir, tags, options)
#     604
#     605
#
# ~\anaconda3\lib\site-packages\tensorflow\python\saved_model\load.py in load_internal(export_dir, tags, options, loader_cls)
#     647   else:
#     648     with ops.init_scope():
# --> 649       root = load_v1_in_v2.load(export_dir, tags)
#     650       root.graph_debug_info = debug_info
#     651   return root
#
# ~\anaconda3\lib\site-packages\tensorflow\python\saved_model\load_v1_in_v2.py in load(export_dir, tags)
#     261   """Load a v1-style SavedModel as an object."""
#     262   loader = _EagerSavedModelLoader(export_dir)
# --> 263   return loader.load(tags=tags)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\saved_model\load_v1_in_v2.py in load(self, tags)
#     244     root.initializer = initializer
#     245     root.asset_paths = asset_paths
# --> 246     signature_functions = self._extract_signatures(wrapped, meta_graph_def)
#     247
#     248     root.signatures = signature_serialization.create_signature_map(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\saved_model\load_v1_in_v2.py in _extract_signatures(self, wrapped, meta_graph_def)
#     156       fetches = {name: out for name, out in signature_def.outputs.items()}
#     157       try:
# --> 158         signature_fn = wrapped.prune(feeds=feeds, fetches=fetches)
#     159       except lift_to_graph.UnliftableError as ex:
#     160         # Mutate the exception to add a bit more detail.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\wrap_function.py in prune(self, feeds, fetches, name, input_signature)
#     372         _structured_output_mapping, fetches, expand_composites=True)
#     373     pruned_graph.structured_input_signature = input_signature
# --> 374     pruned_fn = WrappedFunction(
#     375         pruned_graph, variable_holder=self._variable_holder)
#     376     pruned_fn._num_positional_args = len(flat_feeds)  # pylint: disable=protected-access
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\wrap_function.py in __init__(self, fn_graph, variable_holder, attrs, signature)
#     226     # We call __init__ after lifting variables so that the function's signature
#     227     # properly reflects the new captured inputs.
# --> 228     for f in fn_graph.as_graph_def().library.function:
#     229       context.context().add_function_def(f)
#     230     self._signature = signature
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in as_graph_def(self, from_version, add_shapes)
#    3292     """
#    3293     # pylint: enable=line-too-long
# -> 3294     result, _ = self._as_graph_def(from_version, add_shapes)
#    3295     return result
#    3296
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _as_graph_def(self, from_version, add_shapes)
#    3209         data = pywrap_tf_session.TF_GetBuffer(buf)
#    3210       graph = graph_pb2.GraphDef()
# -> 3211       graph.ParseFromString(compat.as_bytes(data))
#    3212       # Strip the experimental library field iff it's empty.
#    3213       if not graph.library.function:
#
# ~\anaconda3\lib\site-packages\google\protobuf\message.py in ParseFromString(self, serialized)
#     197     """
#     198     self.Clear()
# --> 199     return self.MergeFromString(serialized)
#     200
#     201   def SerializeToString(self, **kwargs):
#
# ~\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py in MergeFromString(self, serialized)
#    1143     length = len(serialized)
#    1144     try:
# -> 1145       if self._InternalParse(serialized, 0, length) != length:
#    1146         # The only reason _InternalParse would return early is if it
#    1147         # encountered an end-group tag.
#
# ~\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py in InternalParse(self, buffer, pos, end)
#    1210         pos = new_pos
#    1211       else:
# -> 1212         pos = field_decoder(buffer, new_pos, end, self, field_dict)
#    1213         if field_desc:
#    1214           self._UpdateOneofState(field_desc)
#
# ~\anaconda3\lib\site-packages\google\protobuf\internal\decoder.py in DecodeRepeatedField(buffer, pos, end, message, field_dict)
#     731           raise _DecodeError('Truncated message.')
#     732         # Read sub-message.
# --> 733         if value.add()._InternalParse(buffer, pos, new_pos) != new_pos:
#     734           # The only reason _InternalParse would return early is if it
#     735           # encountered an end-group tag.
#
# ~\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py in InternalParse(self, buffer, pos, end)
#    1210         pos = new_pos
#    1211       else:
# -> 1212         pos = field_decoder(buffer, new_pos, end, self, field_dict)
#    1213         if field_desc:
#    1214           self._UpdateOneofState(field_desc)
#
# ~\anaconda3\lib\site-packages\google\protobuf\internal\decoder.py in DecodeMap(buffer, pos, end, message, field_dict)
#     892
#     893       if is_message_map:
# --> 894         value[submsg.key].CopyFrom(submsg.value)
#     895       else:
#     896         value[submsg.key] = submsg.value
#
# ~\anaconda3\lib\site-packages\google\protobuf\internal\containers.py in __getitem__(self, key)
#     578       return self._values[key]
#     579     except KeyError:
# --> 580       new_element = self._message_descriptor._concrete_class()
#     581       new_element._SetListener(self._message_listener)
#     582       self._values[key] = new_element
#
# KeyboardInterrupt:
